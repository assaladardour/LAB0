# %%
pip install klib
# Out:
# Collecting klib
#   Using cached klib-1.0.5-py3-none-any.whl (20 kB)
# Collecting numpy<2.0.0,>=1.16.3
#   Using cached numpy-1.23.4-cp310-cp310-win_amd64.whl (14.6 MB)
# Collecting scipy<2.0.0,>=1.1.0
#   Using cached scipy-1.9.3-cp310-cp310-win_amd64.whl (40.1 MB)
# Collecting matplotlib<4.0.0,>=3.0.3
#   Using cached matplotlib-3.6.2-cp310-cp310-win_amd64.whl (7.2 MB)
# Collecting pandas<2.0.0,>=1.2.0
#   Using cached pandas-1.5.1-cp310-cp310-win_amd64.whl (10.4 MB)
# Collecting Jinja2<4.0.0,>=3.0.3
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting seaborn<0.12.0,>=0.11.2
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.1-cp310-cp310-win_amd64.whl (17 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\assal\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (9.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\assal\appdata\roaming\python\python310\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (2.8.2)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.6-cp310-cp310-win_amd64.whl (163 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\assal\appdata\roaming\python\python310\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\assal\appdata\roaming\python\python310\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\assal\appdata\local\programs\python\python310\lib\site-packages (from pandas<2.0.0,>=1.2.0->klib) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\assal\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.0.3->klib) (1.16.0)
# Installing collected packages: numpy, MarkupSafe, kiwisolver, fonttools, cycler, scipy, pandas, Jinja2, contourpy, matplotlib, seaborn, klib
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\assal\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\Users\\assal\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\fontTools\\otlLib\\optimize\\gpos.py'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 22.0.4; however, version 22.3 is available.
# You should consider upgrading via the 'c:\Users\assal\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import klib
import pandas as pd

df = pd.read_csv('https://github.com/akanz1/klib/raw/main/examples/NFL_DATASET.csv')

# %%
df_cleaned = klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (183460, 63) - Remaining NAs: 1757318
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 4
#      of which 1 single valued.     Columns: ['play_attempted']
# Dropped missing values: 520667
# Reduced memory by at least: 65.86 MB (-70.23%)

# %%
klib.corr_plot(df_cleaned, annot=False)
# Out:
# c:\Users\assal\AppData\Local\Programs\Python\Python310\lib\site-packages\klib\describe.py:246: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr(method=method)
# <AxesSubplot: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.corr_plot(df_cleaned, split='pos', annot=False)
# Out:
# Displaying positive correlations. Specify a positive "threshold" to limit the results further.
# <AxesSubplot: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.corr_plot(df_cleaned, split='neg', annot=False)
# Out:
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.
# <AxesSubplot: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.corr_plot(df_cleaned, target='Touchdown')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\assal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\assal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\assal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Touchdown'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 klib.corr_plot(df_cleaned, target='Touchdown')
#
# File c:\Users\assal\AppData\Local\Programs\Python\Python310\lib\site-packages\klib\describe.py:350, in corr_plot(data, split, threshold, target, method, cmap, figsize, annot, dev, **kwargs)
#     346 _validate_input_bool(dev, "dev")
#     348 data = pd.DataFrame(data)
# --> 350 corr = corr_mat(
#     351     data,
#     352     split=split,
#     353     threshold=threshold,
#     354     target=target,
#     355     method=method,
#     356     colored=False,
#     357 )
#     359 mask = np.zeros_like(corr, dtype=bool)
#     361 if target is None:
#
# File c:\Users\assal\AppData\Local\Programs\Python\Python310\lib\site-packages\klib\describe.py:234, in corr_mat(data, split, threshold, target, method, colored)
#     232 target_data = []
#     233 if isinstance(target, str):
# --> 234     target_data = data[target]
#     235     data = data.drop(target, axis=1)
#     237 elif isinstance(target, (list, pd.Series, np.ndarray)):
#
# File c:\Users\assal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3804, in DataFrame.__getitem__(self, key)
#    3802 if self.columns.nlevels > 1:
#    3803     return self._getitem_multilevel(key)
# -> 3804 indexer = self.columns.get_loc(key)
#    3805 if is_integer(indexer):
#    3806     indexer = [indexer]
#
# File c:\Users\assal\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Touchdown'

# %%
klib.corr_mat (df_cleaned)
# Out:
# <style type="text/css">
# #T_67244_row0_col0, #T_67244_row0_col7, #T_67244_row0_col8, #T_67244_row0_col10, #T_67244_row0_col11, #T_67244_row0_col12, #T_67244_row0_col13, #T_67244_row0_col20, #T_67244_row0_col22, #T_67244_row0_col31, #T_67244_row0_col33, #T_67244_row0_col34, #T_67244_row0_col36, #T_67244_row0_col38, #T_67244_row0_col40, #T_67244_row0_col42, #T_67244_row0_col43, #T_67244_row0_col44, #T_67244_row1_col1, #T_67244_row1_col2, #T_67244_row1_col5, #T_67244_row1_col7, #T_67244_row1_col8, #T_67244_row1_col11, #T_67244_row1_col12, #T_67244_row1_col13, #T_67244_row1_col14, #T_67244_row1_col15, #T_67244_row1_col16, #T_67244_row1_col18, #T_67244_row1_col19, #T_67244_row1_col22, #T_67244_row1_col23, #T_67244_row1_col24, #T_67244_row1_col32, #T_67244_row1_col35, #T_67244_row1_col37, #T_67244_row1_col39, #T_67244_row1_col43, #T_67244_row2_col1, #T_67244_row2_col2, #T_67244_row2_col4, #T_67244_row2_col5, #T_67244_row2_col9, #T_67244_row2_col11, #T_67244_row2_col13, #T_67244_row2_col14, #T_67244_row2_col18, #T_67244_row2_col19, #T_67244_row2_col22, #T_67244_row2_col23, #T_67244_row2_col24, #T_67244_row2_col25, #T_67244_row2_col26, #T_67244_row2_col27, #T_67244_row2_col28, #T_67244_row2_col29, #T_67244_row2_col31, #T_67244_row2_col32, #T_67244_row2_col34, #T_67244_row2_col35, #T_67244_row2_col37, #T_67244_row2_col39, #T_67244_row2_col42, #T_67244_row2_col43, #T_67244_row3_col3, #T_67244_row3_col4, #T_67244_row3_col5, #T_67244_row3_col6, #T_67244_row3_col9, #T_67244_row3_col10, #T_67244_row3_col15, #T_67244_row3_col16, #T_67244_row3_col17, #T_67244_row3_col18, #T_67244_row3_col20, #T_67244_row3_col21, #T_67244_row3_col22, #T_67244_row3_col23, #T_67244_row3_col25, #T_67244_row3_col26, #T_67244_row3_col27, #T_67244_row3_col28, #T_67244_row3_col29, #T_67244_row3_col30, #T_67244_row3_col33, #T_67244_row3_col36, #T_67244_row3_col38, #T_67244_row3_col40, #T_67244_row3_col41, #T_67244_row3_col42, #T_67244_row3_col44, #T_67244_row4_col2, #T_67244_row4_col3, #T_67244_row4_col4, #T_67244_row4_col5, #T_67244_row4_col6, #T_67244_row4_col7, #T_67244_row4_col8, #T_67244_row4_col9, #T_67244_row4_col12, #T_67244_row4_col15, #T_67244_row4_col16, #T_67244_row4_col17, #T_67244_row4_col18, #T_67244_row4_col19, #T_67244_row4_col20, #T_67244_row4_col21, #T_67244_row4_col22, #T_67244_row4_col23, #T_67244_row4_col24, #T_67244_row4_col27, #T_67244_row4_col28, #T_67244_row4_col29, #T_67244_row4_col30, #T_67244_row4_col33, #T_67244_row4_col37, #T_67244_row4_col39, #T_67244_row4_col41, #T_67244_row4_col44, #T_67244_row5_col1, #T_67244_row5_col2, #T_67244_row5_col3, #T_67244_row5_col4, #T_67244_row5_col5, #T_67244_row5_col6, #T_67244_row5_col9, #T_67244_row5_col10, #T_67244_row5_col14, #T_67244_row5_col15, #T_67244_row5_col16, #T_67244_row5_col17, #T_67244_row5_col18, #T_67244_row5_col19, #T_67244_row5_col21, #T_67244_row5_col22, #T_67244_row5_col23, #T_67244_row5_col25, #T_67244_row5_col27, #T_67244_row5_col28, #T_67244_row5_col29, #T_67244_row5_col30, #T_67244_row5_col33, #T_67244_row5_col36, #T_67244_row5_col38, #T_67244_row5_col40, #T_67244_row5_col44, #T_67244_row6_col3, #T_67244_row6_col4, #T_67244_row6_col5, #T_67244_row6_col6, #T_67244_row6_col10, #T_67244_row6_col13, #T_67244_row6_col15, #T_67244_row6_col16, #T_67244_row6_col17, #T_67244_row6_col18, #T_67244_row6_col19, #T_67244_row6_col20, #T_67244_row6_col21, #T_67244_row6_col22, #T_67244_row6_col23, #T_67244_row6_col24, #T_67244_row6_col25, #T_67244_row6_col26, #T_67244_row6_col27, #T_67244_row6_col28, #T_67244_row6_col29, #T_67244_row6_col30, #T_67244_row6_col33, #T_67244_row6_col36, #T_67244_row6_col44, #T_67244_row7_col0, #T_67244_row7_col1, #T_67244_row7_col4, #T_67244_row7_col7, #T_67244_row7_col8, #T_67244_row7_col9, #T_67244_row7_col10, #T_67244_row7_col11, #T_67244_row7_col12, #T_67244_row7_col15, #T_67244_row7_col16, #T_67244_row7_col17, #T_67244_row7_col20, #T_67244_row7_col21, #T_67244_row7_col24, #T_67244_row7_col28, #T_67244_row7_col30, #T_67244_row7_col31, #T_67244_row7_col32, #T_67244_row7_col33, #T_67244_ro ...

# %%
klib.dist_plot(df_cleaned['win_prob'])
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot: xlabel='win_prob', ylabel='Density'>

# %%
klib.cat_plot(df, figsize=(50,15))
# Out:
# GridSpec(6, 21)

# %%
plot = klib.corr_plot(df_cleaned, annot=False, figsize=(12,10))
# Out:
# c:\Users\assal\AppData\Local\Programs\Python\Python310\lib\site-packages\klib\describe.py:246: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr(method=method)

# %%
plot. figure.savefig('figure.pdf')
